# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavyapm1960/project/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding, Attention
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load and preprocess data
def load_data(filename):
    with open(filename, encoding='utf-8') as file:
        text = file.read()
    return text.split('\n')

def tokenize(sentences, add_start_end_tokens=True):
    tokenizer = Tokenizer(char_level=False)
    tokenizer.fit_on_texts(sentences)
    if add_start_end_tokens:
        tokenizer.word_index[''] = len(tokenizer.word_index) + 1
        tokenizer.word_index[''] = len(tokenizer.word_index) + 2
    return tokenizer, tokenizer.texts_to_sequences(sentences)


def pad(sequences, maxlen=None):
    return pad_sequences(sequences, padding='post', maxlen=maxlen)

english_sentences = load_data('/content/drive/MyDrive/project/Eng-vocab.txt')
french_sentences = load_data('/content/drive/MyDrive/project/French-vocab.txt')

english_tokenizer, english_tokenized = tokenize(english_sentences)
french_tokenizer, french_tokenized = tokenize(french_sentences, add_start_end_tokens=True)






max_english_length = max(len(sentence) for sentence in english_tokenized)
max_french_length = max(len(sentence) for sentence in french_tokenized)

english_padded = pad(english_tokenized, maxlen=max_english_length)
french_padded = pad(french_tokenized, maxlen=max_french_length)

encoder_input_data = np.array(english_padded)
decoder_input_data = np.array(french_padded)
decoder_output_data = np.zeros_like(decoder_input_data)
decoder_output_data[:, :-1] = decoder_input_data[:, 1:]

# Define model architecture
embedding_size = 128
lstm_units = 256
num_encoder_tokens = len(english_tokenizer.word_index) + 1
num_decoder_tokens = len(french_tokenizer.word_index) + 1

encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(num_encoder_tokens, embedding_size)(encoder_inputs)
encoder_lstm = LSTM(lstm_units, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None,))
decoder_embedding_layer = Embedding(num_decoder_tokens, embedding_size)
decoder_embedding = decoder_embedding_layer(decoder_inputs)
decoder_lstm = LSTM(lstm_units, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)

# Apply attention mechanism
attention = Attention()
context = attention([decoder_outputs, encoder_outputs])
decoder_combined_context = tf.concat([context, decoder_outputs], axis=-1)

decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_combined_context)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Prepare decoder output data
decoder_output_one_hot = np.expand_dims(decoder_output_data, -1)

# Train the model
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_output_data,
    batch_size=128,
    epochs=50
    ,
    validation_split=0.2
)

# Inference setup
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(lstm_units,))
decoder_state_input_c = Input(shape=(lstm_units,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_embedding = decoder_embedding_layer(decoder_inputs)

decoder_outputs, state_h, state_c = decoder_lstm(decoder_embedding, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]

# Apply attention during inference
encoder_outputs_inf, state_h_inf, state_c_inf = encoder_lstm(encoder_embedding)
encoder_states_inf = [state_h_inf, state_c_inf]
attention_inf = Attention()
context_inf = attention_inf([decoder_outputs, encoder_outputs_inf])
decoder_combined_context_inf = tf.concat([context_inf, decoder_outputs], axis=-1)

decoder_outputs_inf = decoder_dense(decoder_combined_context_inf)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs + [encoder_inputs],
    [decoder_outputs_inf] + decoder_states
)

def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1))

    # Populate the first character of target sequence with the start token.
    target_seq[0, 0] = french_tokenizer.word_index['']

    # Sampling loop for a batch of sequences
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value + [input_seq])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = reverse_french_tokenizer.get(sampled_token_index, '')

        # Exit condition: either hit max length or find stop token.
        if sampled_word == '' or len(decoded_sentence) > max_french_length:
            stop_condition = True
        else:
            decoded_sentence += sampled_word + ' '

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence

reverse_french_tokenizer = {i: word for word, i in french_tokenizer.word_index.items()}








# Save the model
model.save('/content/drive/MyDrive/project/translation_model.h5')
# Out:
# Epoch 1/50
# 625/625 [==============================] - 59s 89ms/step - loss: 1.9424 - accuracy: 0.7532 - val_loss: 2.2376 - val_accuracy: 0.6742
# Epoch 2/50
# 625/625 [==============================] - 52s 84ms/step - loss: 1.4151 - accuracy: 0.7823 - val_loss: 1.9395 - val_accuracy: 0.7019
# Epoch 3/50
# 625/625 [==============================] - 53s 84ms/step - loss: 1.1901 - accuracy: 0.8023 - val_loss: 1.7543 - val_accuracy: 0.7198
# Epoch 4/50
# 625/625 [==============================] - 53s 84ms/step - loss: 1.0197 - accuracy: 0.8177 - val_loss: 1.6405 - val_accuracy: 0.7333
# Epoch 5/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.8773 - accuracy: 0.8330 - val_loss: 1.5478 - val_accuracy: 0.7456
# Epoch 6/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.7502 - accuracy: 0.8488 - val_loss: 1.4627 - val_accuracy: 0.7579
# Epoch 7/50
# 625/625 [==============================] - 53s 85ms/step - loss: 0.6301 - accuracy: 0.8656 - val_loss: 1.3908 - val_accuracy: 0.7694
# Epoch 8/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.5236 - accuracy: 0.8820 - val_loss: 1.3377 - val_accuracy: 0.7787
# Epoch 9/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.4344 - accuracy: 0.8974 - val_loss: 1.3028 - val_accuracy: 0.7850
# Epoch 10/50
# 625/625 [==============================] - 48s 78ms/step - loss: 0.3626 - accuracy: 0.9109 - val_loss: 1.2725 - val_accuracy: 0.7911
# Epoch 11/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.3052 - accuracy: 0.9225 - val_loss: 1.2628 - val_accuracy: 0.7955
# Epoch 12/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.2610 - accuracy: 0.9322 - val_loss: 1.2543 - val_accuracy: 0.7983
# Epoch 13/50
# 625/625 [==============================] - 53s 85ms/step - loss: 0.2259 - accuracy: 0.9399 - val_loss: 1.2571 - val_accuracy: 0.8007
# Epoch 14/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.1983 - accuracy: 0.9460 - val_loss: 1.2689 - val_accuracy: 0.8019
# Epoch 15/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.1758 - accuracy: 0.9510 - val_loss: 1.2714 - val_accuracy: 0.8034
# Epoch 16/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.1581 - accuracy: 0.9549 - val_loss: 1.2755 - val_accuracy: 0.8046
# Epoch 17/50
# 625/625 [==============================] - 49s 79ms/step - loss: 0.1428 - accuracy: 0.9583 - val_loss: 1.2998 - val_accuracy: 0.8047
# Epoch 18/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.1300 - accuracy: 0.9614 - val_loss: 1.3099 - val_accuracy: 0.8053
# Epoch 19/50
# 625/625 [==============================] - 53s 85ms/step - loss: 0.1195 - accuracy: 0.9638 - val_loss: 1.3276 - val_accuracy: 0.8053
# Epoch 20/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.1109 - accuracy: 0.9659 - val_loss: 1.3405 - val_accuracy: 0.8063
# Epoch 21/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.1030 - accuracy: 0.9677 - val_loss: 1.3599 - val_accuracy: 0.8055
# Epoch 22/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0969 - accuracy: 0.9690 - val_loss: 1.3682 - val_accuracy: 0.8058
# Epoch 23/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0916 - accuracy: 0.9702 - val_loss: 1.3884 - val_accuracy: 0.8054
# Epoch 24/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0867 - accuracy: 0.9714 - val_loss: 1.3984 - val_accuracy: 0.8058
# Epoch 25/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0830 - accuracy: 0.9722 - val_loss: 1.4097 - val_accuracy: 0.8054
# Epoch 26/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0795 - accuracy: 0.9731 - val_loss: 1.4304 - val_accuracy: 0.8065
# Epoch 27/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0764 - accuracy: 0.9737 - val_loss: 1.4392 - val_accuracy: 0.8057
# Epoch 28/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0743 - accuracy: 0.9743 - val_loss: 1.4491 - val_accuracy: 0.8058
# Epoch 29/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0722 - accuracy: 0.9747 - val_loss: 1.4652 - val_accuracy: 0.8057
# Epoch 30/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0703 - accuracy: 0.9751 - val_loss: 1.4731 - val_accuracy: 0.8060
# Epoch 31/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0690 - accuracy: 0.9752 - val_loss: 1.4826 - val_accuracy: 0.8065
# Epoch 32/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0671 - accuracy: 0.9757 - val_loss: 1.4939 - val_accuracy: 0.8064
# Epoch 33/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0662 - accuracy: 0.9758 - val_loss: 1.5034 - val_accuracy: 0.8053
# Epoch 34/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0651 - accuracy: 0.9760 - val_loss: 1.5123 - val_accuracy: 0.8057
# Epoch 35/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0639 - accuracy: 0.9762 - val_loss: 1.5132 - val_accuracy: 0.8063
# Epoch 36/50
# 625/625 [==============================] - 52s 84ms/step - loss: 0.0631 - accuracy: 0.9765 - val_loss: 1.5220 - val_accuracy: 0.8056
# Epoch 37/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0625 - accuracy: 0.9766 - val_loss: 1.5289 - val_accuracy: 0.8067
# Epoch 38/50
# 625/625 [==============================] - 52s 84ms/step - loss: 0.0617 - accuracy: 0.9766 - val_loss: 1.5297 - val_accuracy: 0.8064
# Epoch 39/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0611 - accuracy: 0.9767 - val_loss: 1.5312 - val_accuracy: 0.8064
# Epoch 40/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0603 - accuracy: 0.9768 - val_loss: 1.5507 - val_accuracy: 0.8064
# Epoch 41/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0597 - accuracy: 0.9768 - val_loss: 1.5465 - val_accuracy: 0.8061
# Epoch 42/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0592 - accuracy: 0.9769 - val_loss: 1.5543 - val_accuracy: 0.8063
# Epoch 43/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0588 - accuracy: 0.9770 - val_loss: 1.5538 - val_accuracy: 0.8068
# Epoch 44/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0583 - accuracy: 0.9770 - val_loss: 1.5585 - val_accuracy: 0.8068
# Epoch 45/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0579 - accuracy: 0.9771 - val_loss: 1.5676 - val_accuracy: 0.8067
# Epoch 46/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0575 - accuracy: 0.9771 - val_loss: 1.5727 - val_accuracy: 0.8066
# Epoch 47/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0572 - accuracy: 0.9771 - val_loss: 1.5662 - val_accuracy: 0.8067
# Epoch 48/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0566 - accuracy: 0.9772 - val_loss: 1.5786 - val_accuracy: 0.8066
# Epoch 49/50
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0563 - accuracy: 0.9772 - val_loss: 1.5838 - val_accuracy: 0.8068
# Epoch 50/50
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0559 - accuracy: 0.9773 - val_loss: 1.5941 - val_accuracy: 0.8072
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import load_model

# Load the model
loaded_model = load_model('/content/drive/MyDrive/project/translation_model.h5')
# Perform translation
while True:
    input_sentence = input("Enter English sentence to translate (or type 'quit' to exit): ")
    if input_sentence.lower() == 'quit':
        break
    input_seq = english_tokenizer.texts_to_sequences([input_sentence])
    padded_input_seq = pad(input_seq, maxlen=max_english_length)
    translation = decode_sequence(padded_input_seq)
    print("French translation:", translation)
# Out:
# Enter English sentence to translate (or type 'quit' to exit): the man in old car
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 1s 657ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# French translation: j'ai achetã© une
# Enter English sentence to translate (or type 'quit' to exit): the boy
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# French translation: le garã§on
# Enter English sentence to translate (or type 'quit' to exit): the boy in a red car
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# French translation: dans une voiture
# Enter English sentence to translate (or type 'quit' to exit): he is coming in a car
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# French translation: dans la voiture
# Enter English sentence to translate (or type 'quit' to exit): red
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# French translation: moiâ€¯
# Enter English sentence to translate (or type 'quit' to exit): white
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# French translation: est blanc
# Enter English sentence to translate (or type 'quit' to exit): it ws a fantastic day
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# French translation: a ã©tã© bon
# Enter English sentence to translate (or type 'quit' to exit): was good
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# French translation: ã©tait bon
# Enter English sentence to translate (or type 'quit' to exit): let me talk to you
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# French translation: vous me parler
# Enter English sentence to translate (or type 'quit' to exit): i was planning to visit india this year
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# French translation: prã©vois d'ãªtre
# Enter English sentence to translate (or type 'quit' to exit): cats and dogs
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# French translation: les chats ont des
# Enter English sentence to translate (or type 'quit' to exit): the students are not prepared well
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# French translation: quoi faire vraiment
# Enter English sentence to translate (or type 'quit' to exit): quit

# %%
for sample_i in range(7):
    print('English sample {}:  {}'.format(sample_i + 1, english_sentences[sample_i]))
    print('French sample {}:  {}\n'.format(sample_i + 1, french_sentences[sample_i]))
# Out:
# English sample 1:  Hi.
# French sample 1:  Salut!
#
# English sample 2:  Run!
# French sample 2:  Coursâ€¯!
#
# English sample 3:  Run!
# French sample 3:  Courezâ€¯!
#
# English sample 4:  Who?
# French sample 4:  Qui ?
#
# English sample 5:  Wow!
# French sample 5:  Ã‡a alorsâ€¯!
#
# English sample 6:  Fire!
# French sample 6:  Au feu !
#
# English sample 7:  Help!
# French sample 7:  Ã€ l'aideâ€¯!

# %%
# Generate predictions for the evaluation set
predictions = []
for seq_index in range(10):  # Limiting to 5 predictions for simplicity
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    predictions.append(decoded_sentence.strip())

# Evaluate predictions using BLEU score
from nltk.translate.bleu_score import corpus_bleu

# Tokenize reference translations
references = [[sentence.split()] for sentence in french_sentences[:10]]  # Limiting to 5 references for simplicity

# Tokenize predicted translations
hypotheses = [sentence.split() for sentence in predictions]

# Calculate BLEU score
bleu_score = corpus_bleu(references, hypotheses)

# Print BLEU score
print("BLEU Score:", bleu_score)

# Print some translations and their corresponding references for manual inspection
print("\nTranslations and References:")
for i in range(5):
    print("English:", english_sentences[i])
    print("Reference French:", french_sentences[i])
    print("Predicted French:", predictions[i])
    print()
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# BLEU Score: 3.1339430124965956e-238
#
# Translations and References:
# English: Hi.
# Reference French: Salut!
# Predicted French:
#
# English: Run!
# Reference French: Coursâ€¯!
# Predicted French:
#
# English: Run!
# Reference French: Courezâ€¯!
# Predicted French:
#
# English: Who?
# Reference French: Qui ?
# Predicted French:
#
# English: Wow!
# Reference French: Ã‡a alorsâ€¯!
# Predicted French:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
